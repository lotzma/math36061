# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# Load the images.
orig_img = Image.open("parrot.png")
orig_img = orig_img.convert('L')
corr_img = Image.open("parrot-mask.png")
corr_img = corr_img.convert('L')

# Convert to arrays.
Uorig = np.array(orig_img)
Ucorr = np.array(corr_img)
rows, cols = Uorig.shape

# Known is 1 if the pixel is known,
# 0 if the pixel was corrupted.
Known = np.zeros((rows, cols))
for i in range(rows):
    for j in range(cols):
         if Uorig[i, j] == Ucorr[i, j]:
            Known[i, j] = 1

# %matplotlib inline
fig, ax = plt.subplots(1, 2,figsize=(10, 5))
ax[0].imshow(orig_img);
ax[0].set_title("Original Image")
ax[0].axis('off')
ax[1].imshow(corr_img);
ax[1].set_title("Corrupted Image")
ax[1].axis('off');

# %%
orig_img
# Out:
# <PIL.Image.Image image mode=L size=576x432 at 0x7F782203DAC8>

# %%
Uorig.shape
# Out:
# (432, 576, 3)
