# %% [markdown]
# # Spam classification

# %% [markdown]
# In this example, we will build a spam classifier for text messages (SMS).

# %%
import pandas as pd
import csv
import matplotlib as plt
% matplotlib inline
import numpy as np
import numpy.linalg as la
from scipy import sparse
import sklearn
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.utils import shuffle

# %% [markdown]
# We first need to read in the data. The data is contained in a file called SMSSpamCollection. This file consists of 5574 rows, and each row contains a label (ham or spam) and the text message. The label and the text message are separated by a TAB (the TAB key on the keyboard, denoted by '\t' in Python). A convenient way to read the data into Python is by using the read_csv function of the Pandas library.

# %%
# Read in messages using the Pandas library
messages = pd.read_csv('data/SMSSpamCollection', sep='\t', quoting=csv.QUOTE_NONE, names=["label", "message"])
messages = shuffle(messages) # Use random order
print messages
# Out:
#      label                                            message
# 5429  spam  Santa Calling! Would your little ones like a c...
# 3279   ham                        What happened in interview?
# 5369   ham  Just trying to figure out when I'm suppose to ...
# 5318   ham                       Jus finish watching tv... U?
# 4119   ham  Watch lor. I saw a few swatch one i thk quite ...
# 3894   ham                     Have you heard from this week?
# 1181   ham                         I'm in chennai velachery:)
# 5421   ham  I'm at bruce &amp; fowler now but I'm in my mo...
# 1389   ham     Oh k.i think most of wi and nz players unsold.
# 3937   ham     They r giving a second chance to rahul dengra.
# 588    ham  "Pete can you please ring meive hardly gotany ...
# 1472   ham  Oh. U must have taken your REAL Valentine out ...
# 2327   ham  The Xmas story is peace.. The Xmas msg is love...
# 3411   ham  Joy's father is John. Then John is the ____ of...
# 2653   ham                      No need for the drug anymore.
# 4176   ham  How are you doing. How's the queen. Are you go...
# 245    ham              U don't remember that old commercial?
# 330    ham  I'm reading the text i just sent you. Its mean...
# 155    ham  You are everywhere dirt, on the floor, the win...
# 3276   ham  Hurry home u big butt. Hang up on your last ca...
# 3428   ham                 Haha okay... Today weekend leh...
# 3378   ham  Yup. Wun believe wat? U really neva c e msg i ...
# 1047   ham  Do 1 thing! Change that sentence into: "Becaus...
# 1656   ham                             At 7 we will go ok na.
# 586    ham  Tell them u have a headache and just want to u...
# 4601   ham  Hi did u decide wot 2 get 4 his bday if not il...
# 4698   ham  Okey dokey, i‘ll be over in a bit just sorting...
# 1010   ham  Dear Hero,i am leaving to qatar tonite for an ...
# 4418   ham   says that he's quitting at least5times a day ...
# 4950   ham                  I am in bus on the way to calicut
# ...    ...                                                ...
# 4756   ham           U wan 2 haf lunch i'm in da canteen now.
# 3748   ham  Ü neva tell me how i noe... I'm not at home in...
# 119    ham  Hmm...my uncle just informed me that he's payi...
# 4112  spam  URGENT! Your Mobile number has been awarded a ...
# 5364   ham  I'm in inside office..still filling forms.don ...
# 3966   ham                       Love you aathi..love u lot..
# 2828   ham  Oh right, ok. I'll make sure that i do loads o...
# 1742   ham  I can do that! I want to please you both insid...
# 2668   ham                 Why de. You looking good only:-)..
# 3824   ham  Please protect yourself from e-threats. SIB ne...
# 2225   ham  I prefer my free days... Tues, wed, fri oso ca...
# 3756   ham      "Im on gloucesterroad what are uup to later?"
# 4468   ham  She said,'' do u mind if I go into the bedroom...
# 4591   ham  Tomorrow i am not going to theatre. . . So i c...
# 1782   ham                             ;-( oh well, c u later
# 1433   ham             Thanks for ve lovely wisheds. You rock
# 2520   ham         Ok. I only ask abt e movie. U wan ktv oso?
# 2581  spam  U are subscribed to the best Mobile Content Se...
# 5490   ham                            K. I will sent it again
# 3286   ham  They are just making it easy to pay back. I ha...
# 84     ham                                     Yup next stop.
# 2150   ham                 Waaaat?? Lololo ok next time then!
# 3667   ham  I'm turning off my phone. My moms telling ever...
# 2641   ham    Pandy joined 4w technologies today.he got job..
# 4538   ham         Normally i use to drink more water daily:)
# 1679   ham  So many people seems to be special at first si...
# 2713   ham  Hey you still want to go for yogasana? Coz if ...
# 4744   ham  I am in hospital da. . I will return home in e...
# 5533   ham  Compliments to you. Was away from the system. ...
# 2665   ham                      He remains a bro amongst bros
#
# [5574 rows x 2 columns]

# %%
# Extract some important information
messages.groupby('label').describe()
# Out:
#                                                         message
# label
# ham   count                                                4827
#       unique                                               4518
#       top                                Sorry, I'll call later
#       freq                                                   30
# spam  count                                                 747
#       unique                                                653
#       top     Please call our customer service representativ...
#       freq                                                    4

# %%
count_vectorizer = CountVectorizer()
bag_of_words = count_vectorizer.fit_transform(messages['message'])
print bag_of_words.shape
# Out:
# (5574, 8713)

# %%
# We can explore the vocabulary
count_vectorizer.vocabulary_
# Out:
# {u'raining': 6259,
#  u'yellow': 8645,
#  u'four': 3354,
#  u'malarky': 4884,
#  u'woods': 8533,
#  u'hanging': 3753,
#  u'looking': 4739,
#  u'electricity': 2900,
#  u'scold': 6698,
#  u'lord': 4748,
#  u'rp176781': 6574,
#  u'callin': 1840,
#  u'09063440451': 237,
#  u'screaming': 6714,
#  u'disturb': 2672,
#  u'prize': 6113,
#  u'nottingham': 5448,
#  u'wednesday': 8367,
#  u'oooh': 5579,
#  u'specially': 7167,
#  u'nigh': 5378,
#  u'tired': 7779,
#  u'snuggles': 7073,
#  u'clubmoby': 2110,
#  u'second': 6730,
#  u'08718720201': 157,
#  u'txtno': 7993,
#  u'scraped': 6708,
#  u'2kbsubject': 455,
#  u'scallies': 6686,
#  u'laxinorficated': 4563,
#  u'cooking': 2271,
#  u'fingers': 3231,
#  u'maraikara': 4908,
#  u'hero': 3857,
#  u'y87': 8623,
#  u'here': 3856,
#  u'specialise': 7166,
#  u'china': 2032,
#  u'dogwood': 2711,
#  u'dorm': 2737,
#  u'08718711108': 156,
#  u'087187262701': 161,
#  u'84122': 773,
#  u'w111wx': 8255,
#  u'kids': 4441,
#  u'84128': 774,
#  u'eastenders': 2845,
#  u'09058091870': 202,
#  u'spotty': 7217,
#  u'golden': 3588,
#  u'replace': 6437,
#  u'brought': 1739,
#  u'sterm': 7293,
#  u'000pes': 2,
#  u'txt': 7986,
#  u'univ': 8064,
#  u'9t': 847,
#  u'cheating': 1987,
#  u'spoke': 7204,
#  u'ec2a': 2853,
#  u'browse': 1743,
#  u'dnt': 2687,
#  u'music': 5242,
#  u'passport': 5753,
#  u'strike': 7345,
#  u'until': 8084,
#  u'paperwork': 5718,
#  u'holy': 3924,
#  u'relax': 6397,
#  u'successful': 7401,
#  u'brings': 1722,
#  u'premarica': 6063,
#  u'hols': 3923,
#  u'yahoo': 8626,
#  u'hurt': 4022,
#  u'99': 841,
#  u'glass': 3559,
#  u'47per': 582,
#  u'hole': 3919,
#  u'hold': 3916,
#  u'95': 836,
#  u'sorry': 7126,
#  u'tirupur': 7783,
#  u'themob': 7687,
#  u'wana': 8300,
#  u'drvgsto': 2797,
#  u'pints': 5884,
#  u'smth': 7057,
#  u'want': 8303,
#  u'organizer': 5621,
#  u'preferably': 6061,
#  u'hon': 3927,
#  u'hoo': 3936,
#  u'travel': 7909,
#  u'how': 3978,
#  u'hot': 3964,
#  u'hor': 3952,
#  u'hos': 3958,
#  u'hop': 3942,
#  u'significance': 6935,
#  u'1172': 319,
#  u'beauty': 1459,
#  u'swing': 7503,
#  u'wan2': 8299,
#  u'plyr': 5931,
#  u'wrong': 8581,
#  u'lololo': 4726,
#  u'bsnl': 1751,
#  u'types': 8001,
#  u'ibored': 4044,
#  u'aroundn': 1221,
#  u'wins': 8477,
#  u'yunny': 8692,
#  u'alian': 1038,
#  u'age16': 986,
#  u'tulip': 7964,
#  u'areyouunique': 1202,
#  u'keeps': 4416,
#  u'souveniers': 7145,
#  u'wind': 8465,
#  u'wine': 8470,
#  u'wc1n': 8344,
#  u'vary': 8165,
#  u'kickoff': 4437,
#  u'82050': 751,
#  u'87575': 799,
#  u'welcomes': 8387,
#  u'lovingly': 4780,
#  u'fit': 3250,
#  u'bringing': 1721,
#  u'fix': 3253,
#  u'max10mins': 4955,
#  u'4eva': 591,
#  u'matured': 4952,
#  u'09095350301': 285,
#  u'wales': 8283,
#  u'hidden': 3871,
#  u'nokia6600': 5411,
#  u'easier': 2841,
#  u'duvet': 2824,
#  u'vouchers': 8248,
#  u'effects': 2875,
#  u'schools': 6696,
#  u'go2sri': 3573,
#  u'silver': 6944,
#  u'rumour': 6597,
#  u'vivekanand': 8232,
#  u'dload': 2685,
#  u'xx': 8611,
#  u'arrow': 1229,
#  u'addicted': 930,
#  u'burial': 1781,
#  u'financial': 3225,
#  u'fgkslpopw': 3194,
#  u'series': 6789,
#  u'allah': 1042,
#  u'spider': 7184,
#  u'bowls': 1656,
#  u'passwords': 5755,
#  u'2day': 442,
#  u'ring': 6522,
#  u'rt': 6580,
#  u'ru': 6584,
#  u'rv': 6605,
#  u'forwarding': 3351,
#  u'rr': 6577,
#  u'rs': 6578,
#  u'help08714742804': 3844,
#  u'sms': 7052,
#  u'rd': 6299,
#  u'neft': 5331,
#  u'noice': 5406,
#  u'09061701851': 225,
#  u'ofcourse': 5512,
#  u'dracula': 2760,
#  u'nice': 5371,
#  u'toking': 7822,
#  u'checked': 1991,
#  u'ate': 1274,
#  u'shelves': 6849,
#  u'atm': 1280,
#  u'ups': 8100,
#  u'shipped': 6863,
#  u'clothes': 2104,
#  u'veggie': 8175,
#  u'kfc': 4430,
#  u'wasn': 8319,
#  u'177': 368,
#  u'millers': 5048,
#  u'basketball': 1418,
#  u'service': 6794,
#  u'09061743386': 228,
#  u'engagement': 2938,
#  u'xin': 8606,
#  u'wedlunch': 8366,
#  u'needed': 5325,
#  u'listed': 4676,
#  u'hiya': 3896,
#  u'listen': 4677,
#  u'wisdom': 8482,
#  u'termsapply': 7629,
#  u'trek': 7922,
#  u'peril': 5811,
#  u'showed': 6903,
#  u'saeed': 6620,
#  u'howu': 3984,
#  u'tree': 7921,
#  u'crave': 2335,
#  u'project': 6141,
#  u'howz': 3985,
#  u'bridgwater': 1713,
#  u'feeling': 3173,
#  u'boston': 1644,
#  u'09061749602': 233,
#  u'selflessness': 6762,
#  u'9755': 837,
#  u'alive': 1040,
#  u'9758': 838,
#  u'affairs': 964,
#  u'escalator': 2989,
#  u'tomorro': 7834,
#  u'responsible': 6477,
#  u'witot': 8498,
#  u'andros': 1102,
#  u'okie': 5543,
#  u'causing': 1919,
#  u'doors': 2736,
#  u'season': 6727,
#  u'hun': 4010,
#  u'shall': 6828,
#  u'doin': 2712,
#  u'victoria': 8195,
#  u'doit': 2715,
#  u'swiss': 7504,
#  u'errors': 2983,
#  u'mouth': 5184,
#  u'daywith': 2474,
#  u'letter': 4616,
#  u'thriller': 7738,
#  u'released': 6399,
#  u'marsms': 4924,
#  u'camp': 1850,
#  u'passes': 5750,
#  u'spend': 7179,
#  u'41685': 554,
#  u'tech': 7596,
#  u'neekunna': 5330,
#  u'scream': 6712,
#  u'came': 1848,
#  u'marvel': 4926,
#  u'saying': 6682,
#  u'bomb': 1620,
#  u'prin': 6098,
#  u'insects': 4168,
#  u'advisors': 959,
#  u'teresa': 7625,
#  u'prix': 6111,
#  u'gauge': 3486,
#  u'buzzzz': 1806,
#  u'participate': 5737,
#  u'lessons': 4613,
#  u'busy': 1793,
#  u'menu': 5015,
#  u'mens': 5009,
#  u'cougar': 2298,
#  u'touched': 7877,
#  u'rich': 6512,
#  u'rice': 6511,
#  u'pocked': 5951,
#  u'plate': 5906,
#  u'0871277810810': 128,
#  u'platt': 5907,
#  u'new': 5358,
#  u'net': 5343,
#  u'unfortunately': 8052,
#  u'bus8': 1788,
#  u'kittum': 4462,
#  u'asssssholeeee': 1262,
#  u'piggy': 5877,
#  u'respond': 6472,
#  u'disaster': 2653,
#  u'fair': 3118,
#  u'rupaul': 6601,
#  u'goodnight': 3603,
#  u'result': 6486,
#  u'bleh': 1579,
#  u'best': 1513,
#  u'lotz': 4762,
#  u'ctargg': 2378,
#  u'lots': 4757,
#  u'lotr': 4756,
#  u'rings': 6524,
#  u'80122300p': 738,
#  u'stamps': 7249,
#  u'score': 6701,
#  u'glasgow': 3558,
#  u'men': 5008,
#  u'nationwide': 5298,
#  u'nature': 5301,
#  u'rolled': 6552,
#  u'rajini': 6265,
#  u'icicibank': 4050,
#  u'wtc': 8586,
#  u'wtf': 8587,
#  u'wth': 8588,
#  u'roller': 6553,
#  u'pity': 5889,
#  u'accident': 892,
#  u'country': 2307,
#  u'macedonia': 4840,
#  u'planned': 5903,
#  u'lookin': 4738,
#  u'tomarrow': 7830,
#  u'machan': 4842,
#  u'login': 4718,
#  u'genus': 3517,
#  u'asked': 1249,
#  u'30th': 500,
#  u'itried2tell': 4252,
#  u'2nd': 466,
#  u'happenin': 3761,
#  u'21870000': 411,
#  u'sk38xh': 6982,
#  u'250': 424,
#  u'255': 426,
#  u'9ja': 845,
#  u'billing': 1543,
#  u'source': 7141,
#  u'fri': 3391,
#  u'fro': 3412,
#  u'frm': 3403,
#  u'much': 5217,
#  u'wuld': 8593,
#  u'stadium': 7241,
#  u'parents': 5729,
#  u'obese': 5494,
#  u'life': 4630,
#  u'dave': 2469,
#  u'lift': 4635,
#  u'chile': 2028,
#  u'child': 2023,
#  u'25p': 427,
#  u'spin': 7187,
#  u'bridal': 1711,
#  u'chill': 2029,
#  u'unsold': 8078,
#  u'3680': 517,
#  u'09058091854': 201,
#  u'2wks': 482,
#  u'selfindependence': 6760,
#  u'meetin': 4988,
#  u'kidz': 4442,
#  u'42810': 560,
#  u'a21': 851,
#  u'congratulation': 2229,
#  u'played': 5909,
#  u'078': 38,
#  u'player': 5910,
#  u'feed': 3170,
#  u'swalpa': 7482,
#  u'things': 7708,
#  u'honi': 3934,
#  u'sometext': 7097,
#  u'dha': 2590,
#  u'craigslist': 2328,
#  u'split': 7199,
#  u'babies': 1356,
#  u'4fil': 593,
#  u'08718727870150ppm': 168,
#  u'tops': 7863,
#  u'ppm150': 6031,
#  u'tune': 7966,
#  u'academic': 884,
#  u'dontplease': 2732,
#  u'nachos': 5267,
#  u'xxxxxxxxxxxxxx': 8621,
#  u'opinions': 5592,
#  u'gigolo': 3542,
#  u'08701752560': 88,
#  u'sleeps': 7005,
#  u'sleepy': 7007,
#  u'nydc': 5485,
#  u'87121': 794,
#  u'waht': 8276,
#  u'rushing': 6603,
#  u'jumpers': 4370,
#  u'hai': 3726,
#  u'enters': 2954,
#  u'ham': 3739,
#  u'duffer': 2811,
#  u'1lemon': 383,
#  u'had': 3721,
#  u'haf': 3723,
#  u'obedient': 5493,
#  u'innocent': 4163,
#  u'has': 3779,
#  u'hat': 3784,
#  u'hav': 3790,
#  u'fromm': 3415,
#  u'possible': 6005,
#  u'twinks': 7981,
#  u'possibly': 6006,
#  u'birth': 1555,
#  u'vday': 8171,
#  u'shadow': 6819,
#  u'unique': 8061,
#  u'remind': 6414,
#  u'steps': 7289,
#  u'9280114': 830,
#  u'ola': 5547,
#  u'right': 6516,
#  u'old': 5551,
#  u'crowd': 2361,
#  u'people': 5799,
#  u'weds': 8368,
#  u'oli': 5552,
#  u'sure': 7463,
#  u'fuuuuck': 3452,
#  u'creep': 2348,
#  u'enemies': 2933,
#  u'08718725756': 159,
#  u'for': 3323,
#  u'bottom': 1650,
#  u'fox': 3358,
#  u'creative': 2343,
#  u'treadmill': 7914,
#  u'muhommad': 5222,
#  u'wocay': 8517,
#  u'suitemates': 7424,
#  u'dental': 2544,
#  u'colleg': 2151,
#  u'starring': 7258,
#  u'losing': 4752,
#  u'memorable': 5005,
#  u'falls': 3127,
#  u'dollars': 2720,
#  u'careabout': 1880,
#  u'solihull': 7086,
#  u'slightly': 7013,
#  u'soc': 7075,
#  u'statements': 7271,
#  u'honeymoon': 3933,
#  u'sol': 7083,
#  u'soo': 7115,
#  u'sos': 7134,
#  u'69696': 680,
#  u's89': 6611,
#  u'soz': 7146,
#  u'janx': 4285,
#  u'4742': 581,
#  u'support': 7456,
#  u'constantly': 2244,
#  u'knowing': 4473,
#  u'halla': 3736,
#  u'greatness': 3658,
#  u'jane': 4282,
#  u'happy': 3768,
#  u'b4280703': 1347,
#  u'offer': 5518,
#  u'6wu': 700,
#  u'paypal': 5780,
#  u'notifications': 5445,
#  u'onluy': 5570,
#  u'fiting': 3251,
#  u'congratulations': 2230,
#  u'inside': 4171,
#  u'pest': 5831,
#  u'lays': 4567,
#  u'smashed': 7034,
#  u'151': 360,
#  u'150': 350,
#  u'153': 361,
#  u'half8th': 3734,
#  u'textbook': 7647,
#  u'exist': 3064,
#  u'accounting': 901,
#  u'ericsson': 2977,
#  u'dealer': 2481,
#  u'norm150p': 5429,
#  u'80160': 740,
#  u'floor': 3281,
#  u'actor': 922,
#  u'uttered': 8139,
#  u'flood': 3280,
#  u'republic': 6448,
#  u'ambitious': 1069,
#  u'smell': 7036,
#  u'truffles': 7940,
#  u'intend': 4184,
#  u'fathima': 3152,
#  u'07742676969': 32,
#  u'outage': 5645,
#  u'mre': 5195,
#  u'hollalater': 3922,
#  u'jewelry': 4317,
#  u'nxt': 5482,
#  u'loveme': 4773,
#  u'preponed': 6070,
#  u'bakra': 1377,
#  u'07732584351': 30,
#  u'mummy': 5230,
#  u'time': 7770,
#  u'push': 6208,
#  u'timi': 7772,
#  u'6230': 664,
#  u'sday': 6721,
#  u'chain': 1949,
#  u'whoever': 8436,
#  u'saibaba': 6625,
#  u'cudnt': 2392,
#  u'3ss': 539,
#  u'boltblue': 1619,
#  u'oso': 5631,
#  u'competition': 2185,
#  u'baller': 1381,
#  u'overdid': 5665,
#  u'lara': 4538,
#  u'macha': 4841,
#  u'comuk': 2206,
#  u'followin': 3304,
#  u'macho': 4845,
#  u'machi': 4843,
#  u'jeri': 4309,
#  u'k718': 4385,
#  u'prepaid': 6066,
#  u'doke': 2716,
#  u'minuts': 5072,
#  u'cheap': 1984,
#  u'maretare': 4911,
#  u'choice': 2044,
#  u'pleassssssseeeeee': 5919,
#  u'5min': 645,
#  u'exact': 3045,
#  u'28days': 434,
#  u'minute': 5070,
#  u'tear': 7592,
#  u'leave': 4587,
#  u'pretsovru': 6087,
#  u'settle': 6801,
#  u'team': 7590,
#  u'loads': 4703,
#  u'prevent': 6089,
#  u'spiritual': 7191,
#  u'rents': 6431,
#  u'videochat': 8199,
#  u'sigh': 6930,
#  u'prediction': 6058,
#  u'sign': 6933,
#  u'08712402972': 121,
#  u'erotic': 2980,
#  u'shirts': 6866,
#  u'rentl': 6430,
#  u'workand': 8543,
#  u'headset': 3811,
#  u'celebrated': 1933,
#  u'melt': 5001,
#  u'current': 2403,
#  u'300': 489,
#  u'axel': 1340,
#  u'thecd': 7679,
#  u'heltini': 3850,
#  u'ground': 3673,
#  u'freaky': 3371,
#  u'unintentionally': 8060,
#  u'funeral': 3443,
#  u'understanding': 8044,
#  u'yards': 8633,
#  u'address': 933,
#  u'alone': 1051,
#  u'along': 1052,
#  u'neville': 5356,
#  u'brilliant': 1717,
#  u'300603': 491,
#  u'wherever': 8425,
#  u'bw': 1807,
#  u'yetty': 8655,
#  u'studies': 7364,
#  u'influx': 4148,
#  u'love': 4769,
#  u'prefer': 6060,
#  u'bloody': 1596,
#  u'fake': 3120,
#  u'thesedays': 7697,
#  u'gotbabes': 3618,
#  u'red': 6363,
#  u'crammed': 2329,
#  u'working': 8545,
#  u'positive': 6000,
#  u'angry': 1104,
#  u'tightly': 7763,
#  u'wicket': 8446,
#  u'opposed': 5595,
#  u'wondering': 8528,
#  u'films': 3217,
#  u'trishul': 7929,
#  u'loving': 4779,
#  u'09065394973': 255,
#  u'afford': 969,
#  u'ooooooh': 5581,
#  u'appendix': 1164,
#  u'everywhere': 3030,
#  u'ip4': 4216,
#  u'scratches': 6710,
#  u'easiest': 2842,
#  u'behalf': 1489,
#  u'logos': 4722,
#  u'valued': 8157,
#  u'hussey': 4026,
#  u'pretend': 6085,
#  u'lttrs': 4796,
#  u'printing': 6105,
#  u'values': 8158,
#  u'following': 3305,
#  u'logon': 4721,
#  u'mesages': 5020,
#  u'muah': 5216,
#  u'awesome': 1335,
#  u'weasels': 8354,
#  u'parachute': 5720,
#  u'88066': 802,
#  u'hides': 3873,
#  u'allowed': 1048,
#  u'offense': 5517,
#  u'dooms': 2734,
#  u'poking': 5961,
#  u'meive': 4996,
#  u'62220cncl': 663,
#  u'fps': 3359,
#  u'elephant': 2901,
#  u'69200': 678,
#  u'lido': 4627,
#  u'laundry': 4558,
#  u'datz': 2468,
#  u'23f': 417,
#  u'23g': 418,
#  u'spot': 7216,
#  u'dats': 2467,
#  u'suntec': 7445,
#  u'unclaimed': 8031,
#  u'date': 2463,
#  u'such': 7403,
#  u'data': 2462,
#  u'brainless': 1684,
#  u'disagreeable': 2650,
#  u'stress': 7338,
#  u'surfing': 7466,
#  u'natural': 5300,
#  u'sp': 7148,
#  u'st': 7238,
#  u'complaining': 2188,
#  u'si': 6923,
#  u'sh': 6816,
#  u'so': 7074,
#  u'sn': 7058,
#  u'swollen': 7506,
#  u'sc': 6685,
#  u'misplaced': 5080,
#  u'sg': 6815,
#  u'hol': 3914,
#  u'se': 6723,
#  u'sd': 6720,
#  u'drunken': 2796,
#  u'bootydelious': 1636,
#  u'speedchat': 7173,
#  u'years': 8641,
#  u'professors': 6134,
#  u'course': 2313,
#  u'studentfinancial': 7362,
#  u'konw': 4482,
#  u'disconnect': 2658,
#  u'jia': 4320,
#  u'avin': 1324,
#  u'attraction': 1292,
#  u'jiu': 4323,
#  u'930': 832,
#  u'decades': 2491,
#  u'instantly': 4178,
#  u'conveying': 2264,
#  u'matches': 4938,
#  u'smarter': 7032,
#  u'n9dx': 5264,
#  u'feelin': 3172,
#  u'records': 6357,
#  u'subscribers': 7393,
#  u'sorted': 7129,
#  u'twilight': 7980,
#  u'maintaining': 4876,
#  u'matched': 4937,
#  u'pokkiri': 5962,
#  u'shouted': 6898,
#  u'83435': 768,
#  u'didn': 2608,
#  u'gain': 3461,
#  u'quarter': 6227,
#  u'sonetimes': 7110,
#  u'retrieve': 6492,
#  u'padhe': 5691,
#  u'receipt': 6338,
#  u'disasters': 2654,
#  u'pataistha': 5757,
#  u'naked': 5273,
#  u'blu': 1601,
#  u'alwa': 1063,
#  u'83383': 767,
#  u'wiskey': 8490,
#  u'trauma': 7907,
#  u'internet': 4193,
#  u'hcl': 3803,
#  u'flurries': 3290,
#  u'ppt150x3': 6032,
#  u'sheffield': 6846,
#  u'1131': 315,
#  u'million': 5049,
#  u'possibility': 6004,
#  u'quite': 6239,
#  u'deliver': 2531,
#  u'grandma': 3641,
#  u'vijaykanth': 8206,
#  u'raed': 6252,
#  u'training': 7893,
#  u'thankyou': 7666,
#  u'rael': 6253,
#  u'dunno': 2817,
#  u'swtheart': 7509,
#  u'initiate': 4157,
#  u'newquay': 5362,
#  u'hooch': 3937,
#  u'neglect': 5333,
#  u'20m12aq': 408,
#  u'emotion': 2920,
#  u'oni': 5567,
#  u'frwd': 3421,
#  u'spoken': 7205,
#  u'potter': 6017,
#  u'one': 5565,
#  u'spanish': 7155,
#  u'vote': 8244,
#  u'custom': 2410,
#  u'open': 5583,
#  u'city': 2064,
#  u'sozi': 7147,
#  u'bite': 1562,
#  u'uks': 8018,
#  u'ukp': 8017,
#  u'indicate': 4141,
#  u'fml': 3296,
#  u'stifled': 7300,
#  u'stuffed': 7371,
#  u'definitly': 2518,
#  u'bits': 1564,
#  u'violated': 8213,
#  u'floppy': 3282,
#  u'snatch': 7062,
#  u'dudes': 2808,
#  u'fooled': 3315,
#  u'boyfriend': 1677,
#  u'remembr': 6412,
#  u'breadstick': 1696,
#  u'scrumptious': 6718,
#  u'cutefrnd': 2417,
#  u'arun': 1236,
#  u'arul': 1235,
#  u'attracts': 1294,
#  u'illness': 4082,
#  u'sao': 6651,
#  u't4get2text': 7520,
#  u'sam': 6638,
#  u'sac': 6613,
#  u'turned': 7970,
#  u'afternoons': 978,
#  u'sae': 6619,
#  u'sad': 6618,
#  u'woah': 8516,
#  u'say': 6679,
#  u'sar': 6653,
#  u'saw': 6678,
#  u'sat': 6662,
#  u'sport': 7212,
#  u'zoe': 8705,
#  u'babysit': 1360,
#  u'aproach': 1186,
#  u'15pm': 363,
#  u'note': 5439,
#  u'taka': 7536,
#  u'algarve': 1034,
#  u'take': 7537,
#  u'wanting': 8306,
#  u'ericson': 2976,
#  u'handing': 3744,
#  u'printer': 6104,
#  u'opposite': 5596,
#  u'knew': 4468,
#  u'buffet': 1765,
#  u'printed': 6103,
#  u'knee': 4466,
#  u'pages': 5693,
#  u'operate': 5589,
#  u'sall': 6634,
#  u'02085076972': 13,
#  u'phil': 5844,
#  u'infections': 4146,
#  u'drive': 2779,
#  u'werethe': 8400,
#  u'salt': 6637,
#  u'annoncement': 1112,
#  u'walking': 8289,
#  u'5wq': 653,
#  u'inclu': 4120,
#  u'bright': 1715,
#  u'5wb': 650,
#  u'5we': 651,
#  u'applyed': 1170,
#  u'slow': 7021,
#  u'farting': 3144,
#  u'robs': 6542,
#  u'coaxing': 2126,
#  u'foward': 3356,
#  u'tears': 7593,
#  u'going': 3584,
#  u'actin': 915,
#  u'hockey': 3910,
#  u'slob': 7018,
#  u'caroline': 1894,
#  u'carolina': 1893,
#  u'b4u': 1348,
#  u'psychiatrist': 6179,
#  u'4882': 584,
#  u'freezing': 3382,
#  u'murali': 5235,
#  u'awaiting': 1330,
#  u'settings': 6800,
#  u'recpt': 6360,
#  u'borrow': 1642,
#  u'ahmad': 1001,
#  u'worried': 8551,
#  u'racal': 6248,
#  u'priest': 6097,
#  u'roger': 6549,
#  u'worries': 8552,
#  u'tortilla': 7867,
#  u'where': 8423,
#  u'xmas': 8607,
#  u'wud': 8591,
#  u'espe': 2993,
#  u'anyways': 1146,
#  u'pisces': 5885,
#  u'cttargg': 2382,
#  u'8883': 807,
#  u'dormitory': 2738,
#  u'x29': 8599,
#  u'refreshed': 6377,
#  u'availa': 1315,
#  u'olayiwola': 5550,
#  u'jobs': 4328,
#  u'screen': 6715,
#  u'punto': 6198,
#  u'concentrate': 2208,
#  u'footie': 3320,
#  u'amore': 1082,
#  u'spark': 7158,
#  u'listening2the': 4681,
#  u'5249': 634,
#  u'many': 4904,
#  u'residency': 6463,
#  u'7876150ppm': 720,
#  u'expression': 3088,
#  u'hurts': 4024,
#  u'call2optout': 1830,
#  u'anti': 1131,
#  u'3000': 490,
#  u'mapquest': 4906,
#  u'boat': 1610,
#  u'caring': 1888,
#  u'swashbuckling': 7486,
#  u'stretch': 7342,
#  u'west': 8403,
#  u'breath': 1703,
#  u'reflex': 6375,
#  u'wants': 8307,
#  u'gist': 3550,
#  u'hlday': 3898,
#  u'coughing': 2300,
#  u'09111032124': 293,
#  u'820554ad0a1705572711': 752,
#  u'photos': 5856,
#  u'300p': 493,
#  u'09058097218': 214,
#  u'aiya': 1013,
#  u'single': 6958,
#  u'n\xecte': 5489,
#  u'squeezed': 7231,
#  u'situation': 6975,
#  u'3uz': 540,
#  u'ive': 4259,
#  u'wire3': 8481,
#  u'purse': 6207,
#  u'bros': 1734,
#  u'blah': 1570,
#  u'limping': 4655,
#  u'verified': 8182,
#  u'0125698789': 8,
#  u'thinkin': 7711,
#  u'mk17': 5102,
#  u'08719181259': 176,
#  u'unemployed': 8049,
#  u'sterling': 7292,
#  u'askin': 1250,
#  u'singapore': 6956,
#  u'mtnl': 5214,
#  u'cheers': 1999,
#  u'callon': 1842,
#  u'cheery': 2000,
#  u'italian': 4246,
#  u'defo': 2519,
#  u'88888': 809,
#  u'natalie2k9': 5295,
#  u'costa': 2292,
#  u'volcanoes': 8240,
#  u'nothin': 5442,
#  u'costs': 2294,
#  u'1winaweek': 394,
#  u'grumpy': 3681,
#  u'hubby': 3997,
#  u'dimension': 2630,
#  u'summer': 7431,
#  u'jst': 4358,
#  u'being': 1493,
#  u'150p16': 353,
#  u'pc1323': 5782,
#  u'sum1': 7428,
#  u'08714712412': 135,
#  u'88088': 803,
#  u'6089': 658,
#  u'lolnice': 4725,
#  u'ghodbandar': 3534,
#  u'weekly': 8375,
#  u'81151': 748,
#  u'310303': 503,
#  u'excuses': 3056,
#  u'kerala': 4422,
#  u'adsense': 950,
#  u'drugdealer': 2791,
#  u'f4q': 3099,
#  u'starving': 7266,
#  u'proze': 6172,
#  u'aspects': 1256,
#  u'around': 1220,
#  u'lnly': 4700,
#  u'pos': 5994,
#  u'dark': 2450,
#  u'traffic': 7890,
#  u'poly': 5967,
#  u'2geva': 449,
#  u'world': 8548,
#  u'postal': 6008,
#  u'vague': 8148,
#  u'dare': 2449,
#  u'ors': 5626,
#  u'stranger': 7335,
#  u'poo': 5976,
#  u'quizclub': 6243,
#  u'alaipayuthe': 1023,
#  u'gimme': 3543,
#  u'updat': 8090,
#  u'clas': 2074,
#  u'gimmi': 3544,
#  u'slovely': 7020,
#  u'pdate_now': 5783,
#  u'polo': 5966,
#  u'4few': 592,
#  u'trouser': 7935,
#  u'monthlysubscription': 5158,
#  u'playin': 5912,
#  u'5wkg': 652,
#  u'thinks': 7713,
#  u'strewn': 7343,
#  u'memories': 5006,
#  u'noon': 5420,
#  u'otside': 5638,
#  u'910': 828,
#  u'comingdown': 2170,
#  u'power': 6025,
#  u'papa': 5715,
#  u'lapdancer': 4535,
#  u'leadership': 4576,
#  u'97n7qp': 839,
#  u'went': 8394,
#  u'acc': 885,
#  u'stone': 7311,
#  u'comfey': 2166,
#  u'package': 5688,
#  u'aco': 911,
#  u'side': 6929,
#  u'neighbor': 5335,
#  u'act': 913,
#  u'mean': 4971,
#  u'waheeda': 8274,
#  u'burning': 1783,
#  u'450pw': 576,
#  ...}

# %%
# Or a row of the bag-of-words matrix and the corresponding messages
print bag_of_words[10,:]
print messages['message'][10]
# Out:
#   (0, 8668)	1
#   (0, 1853)	1
#   (0, 5832)	1
#   (0, 5917)	1
#   (0, 6522)	1
#   (0, 4996)	1
#   (0, 3773)	1
#   (0, 3617)	1
#   (0, 2345)	1
# I'm gonna be home soon and i don't want to talk about this stuff anymore tonight, k? I've cried enough today.

# %%
# Normalize messages so that the rows have length 1
tfidf = TfidfTransformer()
normalized_bow = tfidf.fit_transform(bag_of_words)
normalized_bow.shape
# Out:
# (5574, 8713)

# %%
# Transform 'spam' and 'ham' into 1 and -1
bin_labels = np.array([1. if x =='spam' else -1. for x in messages['label']])

# %%
# Separate training data from test data
train, train_l, test, test_l = normalized_bow[:1000], bin_labels[:1000], normalized_bow[1000:], bin_labels[1000:]

# %% [markdown]
# Now that we have our data and labels set up, we can run the optimization! Here, we will use a naive implementation of Stochastic Gradient Descent

# %%
def sgd_bt(f, df, X, y, x0, tol, maxiter=1000, rho=0.5, c=0.1):
    """
    Stochastic Gradient Descent with backtracking
    """
    x = np.vstack((x0+2*tol*np.ones(x0.shape),x0)).transpose()
    i = 1
    m, n = X.shape
    while ( la.norm(x[:,i]-x[:,i-1]) > tol ) and ( i < maxiter ):
        # Choose random index
        ind = np.random.randint(m)
        p = -df(x[:,i], X[ind], y[ind])
        # Start backtracking
        alpha = 1
        xnew = x[:,i] + alpha*p
        while (f(xnew, X[ind], y[ind]) >= f(x[:,i], X[ind], y[ind]) + alpha*c*np.dot(p, df(x[:,i], X[ind], y[ind]))):
            alpha = alpha*rho
            xnew = x[:,i] + alpha*p
        x = np.concatenate((x,xnew.reshape((len(x0),1))), axis=1)
        i += 1
    return x[:,1:]

# %%
def f(w, X, y):
    Y = np.concatenate((X.toarray(),
    return np.log(1+np.exp(-y*(sparse.csc_matrix.dot(X.transpose(),w[:-1])+w[-1])))

def df(w, X, y):
    Y = np.concatenate((X.toarray(),[1.]))
    return -Y*y*np.exp(-y*(np.dot(Y,w)))/(1+np.exp(-y*np.dot(Y,w)))

# %%
x = np.ones(8713)
np.concatenate((normalized_bow[10].toarray()[0],np.array([1.])))
# Out:
# array([ 0.,  0.,  0., ...,  0.,  0.,  1.])

# %%
x0 = np.ones(8714)
W = sgd_bt(f, df, train, train_l, x0, 1e-2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-140-589939eede19> in <module>()
#       1 x0 = np.ones(8714)
# ----> 2 W = sgd_bt(f, df, train, train_l, x0, 1e-2)
#
# <ipython-input-87-65b508c18230> in sgd_bt(f, df, X, y, x0, tol, maxiter, rho, c)
#       9         # Choose random index
#      10         ind = np.random.randint(m)
# ---> 11         p = -df(x[:,i], X[ind], y[ind])
#      12         # Start backtracking
#      13         alpha = 1
#
# <ipython-input-138-410575ef6775> in df(w, X, y)
#       3
#       4 def df(w, X, y):
# ----> 5     Y = np.concatenate((X.toarray(),[1.]))
#       6     return -Y*y*np.exp(-y*(np.dot(Y,w)))/(1+np.exp(-y*np.dot(Y,w)))
#
# ValueError: all the input arrays must have same number of dimensions
